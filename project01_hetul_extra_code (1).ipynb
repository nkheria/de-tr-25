# %%
# %sql

USE CATALOG hetul_project01_catalog ;

-- Create schema for demo
CREATE SCHEMA IF NOT EXISTS  capstone_retail_hetul 
COMMENT 'Schema for BI Integration demo with DLT';

# %%
# %sql
USE CATALOG hetul_project01_catalog;

CREATE SCHEMA IF NOT EXISTS bronze COMMENT 'Raw ingested data';
CREATE SCHEMA IF NOT EXISTS silver COMMENT 'Cleaned and conformed data';
CREATE SCHEMA IF NOT EXISTS gold   COMMENT 'Curated analytics for BI';
